# %%
import pandas as pd

# %%
df_museos = pd.read_csv('datos/museos_datosabiertos/2022-05/museos_datosabiertos-06-05-2022/museos_datosabiertos-06-05-2022.csv',sep=',',header=0)

# %%
df_museos
# Out:
#        Cod_Loc  IdProvincia  IdDepartamento  Observaciones  \
# 0      6588100            6            6588            NaN
# 1      6077010            6            6077            NaN
# 2      6035010            6            6035            NaN
# 3      6035010            6            6035            NaN
# 4      6049020            6            6049            NaN
# ...        ...          ...             ...            ...
# 1177  90098040           90           90098            NaN
# 1178  90105080           90           90105            NaN
# 1179  90105080           90           90105            NaN
# 1180  90105070           90           90105            NaN
# 1181  90098040           90           90098            NaN
#
#                                categoria subcategoria     provincia  \
# 0     Espacios de Exhibición Patrimonial       Museos  Buenos Aires
# 1     Espacios de Exhibición Patrimonial       Museos  Buenos Aires
# ...

# %%
df_museos['año_inauguracion'] = df_museos['año_inauguracion'].fillna(0) #convertimos los Nan en 0 para poder parlos a enteros

# %%
df_museos['año_inauguracion'] = df_museos['año_inauguracion'].round(decimals=0).astype(int) #pasamos los datos de la columna a enteros

# %%
df_museos.loc[df_museos.año_inauguracion==0,'año_inauguracion']='s/d' #los datos 0 los ponemos como sin dato

# %%
df_museos = df_museos.fillna('s/d')

# %%
df_museos = df_museos.rename({'Cod_Loc':'cod_localidad','IdProvincia':'id_provincia','IdDepartamento':'id_departamento','categoria':'categoría','Provincia':'provincia','Localidad':'localidad','Nombre':'nombre','direccion':'domicilio',
                                               'CP':'código postal','telefono':'número de teléfono','Mail':'mail','Web':'web'},axis=1)

# %%
df_museos.head()
# Out:
#    cod_localidad  id_provincia  id_departamento Observaciones  \
# 0        6588100             6             6588           s/d
# 1        6077010             6             6077           s/d
# 2        6035010             6             6035           s/d
# 3        6035010             6             6035           s/d
# 4        6049020             6             6049           s/d
#
#                             categoría subcategoria     provincia   localidad  \
# 0  Espacios de Exhibición Patrimonial       Museos  Buenos Aires  9 de Julio
# 1  Espacios de Exhibición Patrimonial       Museos  Buenos Aires   Arrecifes
# 2  Espacios de Exhibición Patrimonial       Museos  Buenos Aires  Avellaneda
# 3  Espacios de Exhibición Patrimonial       Museos  Buenos Aires  Avellaneda
# 4  Espacios de Exhibición Patrimonial       Museos  Buenos Aires        Azul
#
#                                               nombre  \
# 0     Archivo Y Museo Histórico Gral. Julio De Vedia
# ...

# %%
df_museos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1182 entries, 0 to 1181
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cod_localidad        1182 non-null   int64
#  1   id_provincia         1182 non-null   int64
#  2   id_departamento      1182 non-null   int64
#  3   Observaciones        1182 non-null   object
#  4   categoría            1182 non-null   object
#  5   subcategoria         1182 non-null   object
#  6   provincia            1182 non-null   object
#  7   localidad            1182 non-null   object
#  8   nombre               1182 non-null   object
#  9   domicilio            1182 non-null   object
#  10  piso                 1182 non-null   object
#  11  código postal        1182 non-null   object
#  12  cod_area             1182 non-null   object
#  13  número de teléfono   1182 non-null   object
#  14  mail                 1182 non-null   object
# ...

# %%
df_museos.drop_duplicates()
# Out:
#       cod_localidad  id_provincia  id_departamento Observaciones  \
# 0           6588100             6             6588           s/d
# 1           6077010             6             6077           s/d
# 2           6035010             6             6035           s/d
# 3           6035010             6             6035           s/d
# 4           6049020             6             6049           s/d
# ...             ...           ...              ...           ...
# 1177       90098040            90            90098           s/d
# 1178       90105080            90            90105           s/d
# 1179       90105080            90            90105           s/d
# 1180       90105070            90            90105           s/d
# 1181       90098040            90            90098           s/d
#
#                                categoría subcategoria     provincia  \
# 0     Espacios de Exhibición Patrimonial       Museos  Buenos Aires
# ...

# %%
df_museos = df_museos.fillna('s/d')

# %%
df_museos.to_csv('datos/museos_datosabiertos/2022-05/museos_datosabiertos-06-05-2022/museos_datosabiertos-06-05-2022.csv', index=None)
