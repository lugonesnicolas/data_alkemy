# %%
import pandas as pd

# %%
df_bibliotecas = pd.read_csv('datos/biblioteca/2022-05/biblioteca-06-05-2022/biblioteca-06-05-2022.csv',sep=',', header=0)
df_cines = pd.read_csv('datos/cine/2022-05/cine-06-05-2022/cine-06-05-2022.csv',sep=',',header=0)  #Importamos nuestro data frame
df_museos = pd.read_csv('datos/museos_datosabiertos/2022-05/museos_datosabiertos-06-05-2022/museos_datosabiertos-06-05-2022.csv',sep=',',header=0)

# %%
df_bibliotecas_normalized = df_bibliotecas[['cod_localidad','id_provincia','id_departamento','categoria','provincia','localidad','nombre','domicilio','codigo postal','numero de telefono','mail','web']]

# %%
df_cines_normalized = df_cines[['cod_localidad','id_provincia','id_departamento','categoria','provincia','localidad','nombre','domicilio','codigo postal','numero de teléfono','mail','web']]

# %%
df_museos_normalized = df_museos[['cod_localidad','id_provincia','id_departamento','categoria','provincia','localidad','nombre','domicilio','codigo postal','numero de teléfono','mail','web']]

# %%
dfs_concat = pd.concat([df_bibliotecas_normalized, df_cines_normalized, df_museos_normalized], axis=0)

# %%
dfs_concat
# Out:
#       cod_localidad  id_provincia  id_departamento  \
# 0          70049060            70            70049
# 1           2000010             2             2000
# 2           2000010             2             2000
# 3           2000010             2             2000
# 4           2000010             2             2000
# ...             ...           ...              ...
# 1177       90098040            90            90098
# 1178       90105080            90            90105
# 1179       90105080            90            90105
# 1180       90105070            90            90105
# 1181       90098040            90            90098
#
#                                categoría                        provincia  \
# 0                  Bibliotecas Populares                         San Juan
# 1                  Bibliotecas Populares  Ciudad Autónoma de Buenos Aires
# 2                  Bibliotecas Populares  Ciudad Autónoma de Buenos Aires
# 3                  Bibliotecas Populares  Ciudad Autónoma de Buenos Aires
# 4                  Bibliotecas Populares  Ciudad Autónoma de Buenos Aires
# ...                                  ...                              ...
# 1177  Espacios de Exhibición Patrimonial                          Tucumán
# 1178  Espacios de Exhibición Patrimonial                          Tucumán
# 1179  Espacios de Exhibición Patrimonial                          Tucumán
# 1180  Espacios de Exhibición Patrimonial                          Tucumán
# 1181  Espacios de Exhibición Patrimonial                          Tucumán
#
#                    localidad  \
# 0                      Rodeo
# 1     Ciudad de Buenos Aires
# 2     Ciudad de Buenos Aires
# 3     Ciudad de Buenos Aires
# 4     Ciudad de Buenos Aires
# ...                      ...
# 1177          Tafí del Valle
# 1178              Tafí Viejo
# 1179              Tafí Viejo
# 1180       Villa El Cadillal
# 1181          Tafí del Valle
#
#                                                  nombre  \
# 0                  Biblioteca Popular Juan P. Garramuno
# 1           Biblioteca Popular Helena Larroque de Roffo
# 2                      Biblioteca Popular 12 de Octubre
# 3             Biblioteca Popular Villa Pueyrredón Norte
# 4                            Biblioteca Popular Alberdi
# ...                                                 ...
# 1177  Museo Histórico Y Arqueológico Jesuítico La Banda
# 1178                 Mac-Museo Arqueológico El Cadillal
# 1179    Museo Ferroviario De Los Talleres De Tafí Viejo
# 1180             Museo Arqueológico Dr. Ernesto Padilla
# 1181  Asentamientos De Menhires En Las Áreas Arqueol...
#
#                             domicilio código postal número de teléfono  \
# 0                       Santo Domingo          5465                s/d
# 1                        Simbrón 3058      C1417EUD           45010078
# 2                Calle Arengreen 1187      C1405CYM           49880766
# 3                       Cockrane 2334      C1419FMD           45729107
# 4                         Acevedo 666      C1414DJN           47753325
# ...                               ...           ...                ...
# 1177                     La Banda S/N          4000            421 685
# 1178     Centro Principal el Cadillal           s/d                s/d
# 1179  Avda. Pte. Roque Sáenz Peña 234          4103           461 4335
# 1180              Ernesto Padilla S/N          4101           422 2199
# 1181                              s/d           s/d                s/d
#
#                                        mail                             web
# 0                                       s/d                             s/d
# 1              asociacionroffo@yahoo.com.ar                             s/d
# 2            popular12deoctubre@hotmail.com                             s/d
# 3          bibliotecapueyrredon@hotmail.com                             s/d
# 4     bibliotecapopularalberdi@yahoo.com.ar                             s/d
# ...                                     ...                             ...
# 1177                                    s/d                             s/d
# 1178                                    s/d                             s/d
# 1179                                    s/d                             s/d
# 1180                                    s/d                             s/d
# 1181                                    s/d  www.enteculturaltucuman.gov.ar
#
# [3528 rows x 12 columns]

# %%
dfs_concat.to_csv('datos_norm/data_norm.csv', index=None)

# %% [markdown]
# # Datos por categoria y fuente

# %%
dfs_concat.groupby('categoría', as_index=False).count()[['categoría', 'provincia']]
# Out:
#                             categoría  provincia
# 0               Bibliotecas Populares       2017
# 1  Espacios de Exhibición Patrimonial       1182
# 2                       Salas de cine        329

# %%
df_fuentes_categoria = dfs_concat.groupby('categoría', as_index=False).count()[['categoría', 'provincia']]
fuentes =['bibliotecas', 'museos', 'cines']
fuentes_add = df_fuentes_categoria
fuentes_add['fuentes'] = fuentes

# %%
fuentes_add_df = pd.DataFrame(fuentes_add)

# %%
fuentes_add_df
# Out:
#                             categoría  provincia      fuentes
# 0               Bibliotecas Populares       2017  bibliotecas
# 1  Espacios de Exhibición Patrimonial       1182       museos
# 2                       Salas de cine        329        cines

# %%
fuentes_add_df.to_csv('datos_norm/registros_categoria_fuentes.csv', index=None)

# %% [markdown]
# # Datos por provincia y categoria

# %%
dfs_concat.head(5)
# Out:
#    cod_localidad  id_provincia  id_departamento              categoría  \
# 0       70049060            70            70049  Bibliotecas Populares
# 1        2000010             2             2000  Bibliotecas Populares
# 2        2000010             2             2000  Bibliotecas Populares
# 3        2000010             2             2000  Bibliotecas Populares
# 4        2000010             2             2000  Bibliotecas Populares
#
#                          provincia               localidad  \
# 0                         San Juan                   Rodeo
# 1  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
# 2  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
# 3  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
# 4  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
#
#                                         nombre             domicilio  \
# 0         Biblioteca Popular Juan P. Garramuno         Santo Domingo
# 1  Biblioteca Popular Helena Larroque de Roffo          Simbrón 3058
# 2             Biblioteca Popular 12 de Octubre  Calle Arengreen 1187
# 3    Biblioteca Popular Villa Pueyrredón Norte         Cockrane 2334
# 4                   Biblioteca Popular Alberdi           Acevedo 666
#
#   código postal número de teléfono                                   mail  web
# 0          5465                s/d                                    s/d  s/d
# 1      C1417EUD           45010078           asociacionroffo@yahoo.com.ar  s/d
# 2      C1405CYM           49880766         popular12deoctubre@hotmail.com  s/d
# 3      C1419FMD           45729107       bibliotecapueyrredon@hotmail.com  s/d
# 4      C1414DJN           47753325  bibliotecapopularalberdi@yahoo.com.ar  s/d

# %%
df_prov_cat = dfs_concat[['provincia','categoría']]

# %%
df_prov_cat_count = df_prov_cat.groupby(['provincia'])['categoría'].apply(lambda x: x.value_counts())

# %%
df_prov_cat_count = df_prov_cat[['provincia','categoría']]

# %%
df_prov_cat_count.groupby(['provincia','categoría']).value_counts()
# Out:
# provincia                                              categoría
# Buenos Aires                                           Bibliotecas Populares                 543
#                                                        Espacios de Exhibición Patrimonial    152
#                                                        Salas de cine                         106
# Catamarca                                              Bibliotecas Populares                  38
#                                                        Espacios de Exhibición Patrimonial     32
#                                                                                             ...
# Tierra del Fuego                                       Salas de cine                           3
# Tierra del Fuego, Antártida e Islas del Atlántico Sur  Espacios de Exhibición Patrimonial     14
# Tucumán                                                Bibliotecas Populares                  37
#                                                        Espacios de Exhibición Patrimonial     26
#                                                        Salas de cine                           8
# Length: 73, dtype: int64

# %%
df_prov_cat_count.groupby(['provincia','categoría']).value_counts().to_frame()
# Out:
#                                                                                          0
# provincia                                          categoría
# Buenos Aires                                       Bibliotecas Populares               543
#                                                    Espacios de Exhibición Patrimonial  152
#                                                    Salas de cine                       106
# Catamarca                                          Bibliotecas Populares                38
#                                                    Espacios de Exhibición Patrimonial   32
# ...                                                                                    ...
# Tierra del Fuego                                   Salas de cine                         3
# Tierra del Fuego, Antártida e Islas del Atlánti... Espacios de Exhibición Patrimonial   14
# Tucumán                                            Bibliotecas Populares                37
#                                                    Espacios de Exhibición Patrimonial   26
#                                                    Salas de cine                         8
#
# [73 rows x 1 columns]
