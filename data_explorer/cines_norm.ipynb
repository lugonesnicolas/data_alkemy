# %%
import pandas as pd

# %%
df_cines = pd.read_csv('datos/cine/2022-05/cine-06-05-2022/cine-06-05-2022.csv',sep=',',header=0)  #Importamos nuestro data frame

# %%
df_cines  #Exploramos nuestro data frame
# Out:
#       Cod_Loc  IdProvincia  IdDepartamento  Observaciones      Categoría  \
# 0    10049030           10           10049            NaN  Salas de cine
# 1    10091150           10           10091            NaN  Salas de cine
# 2    22140060           22           22140            NaN  Salas de cine
# 3    26091020           26           26091            NaN  Salas de cine
# 4    18007010           18           18007            NaN  Salas de cine
# ..        ...          ...             ...            ...            ...
# 324   6455030            6            6455            NaN  Salas de cine
# 325   6434010            6            6434            NaN  Salas de cine
# 326   6791050            6            6791            NaN  Salas de cine
# 327  10049030           10           10049            NaN  Salas de cine
# 328   6427010            6            6427            NaN  Salas de cine
#
#         Provincia  Departamento    Localidad                           Nombre  \
# ...

# %%
df_cines.columns
# Out:
# Index(['Cod_Loc', 'IdProvincia', 'IdDepartamento', 'Observaciones',
#        'Categoría', 'Provincia', 'Departamento', 'Localidad', 'Nombre',
#        'Dirección', 'Piso', 'CP', 'cod_area', 'Teléfono', 'Mail', 'Web',
#        'Información adicional', 'Latitud', 'Longitud', 'TipoLatitudLongitud',
#        'Fuente', 'tipo_gestion', 'Pantallas', 'Butacas', 'espacio_INCAA',
#        'año_actualizacion'],
#       dtype='object')

# %%
df_cines = df_cines.rename({'Cod_Loc':'cod_localidad','IdProvincia':'id_provincia','IdDepartamento':'id_departamento','Categoría':'categoría','Provincia':'provincia','Localidad':'localidad','Nombre':'nombre','Dirección':'domicilio',
                                               'CP':'código postal','Teléfono':'número de teléfono','Mail':'mail','Web':'web'},axis=1)
#renombramos las columnas detalladas en el challeng

# %%
df_cines.head()
# Out:
#    cod_localidad  id_provincia  id_departamento  Observaciones      categoría  \
# 0       10049030            10            10049            NaN  Salas de cine
# 1       10091150            10            10091            NaN  Salas de cine
# 2       22140060            22            22140            NaN  Salas de cine
# 3       26091020            26            26091            NaN  Salas de cine
# 4       18007010            18            18007            NaN  Salas de cine
#
#     provincia  Departamento    localidad                       nombre  \
# 0   Catamarca       Capital    Catamarca                 Cinemacenter
# 1   Catamarca   Santa Maria  Santa María  Centro Cultural San Agustín
# 2       Chaco  San Fernando  Resistencia        Los Cines De La Costa
# 3      Chubut     Sarmiento    Sarmiento    Deborah Jones De Williams
# 4  Corrientes   Bella Vista  Bella Vista                     Fantasio
#
#                                domicilio  ... Información adicional  \
# ...

# %%
df_cines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cod_localidad          329 non-null    int64
#  1   id_provincia           329 non-null    int64
#  2   id_departamento        329 non-null    int64
#  3   Observaciones          0 non-null      float64
#  4   categoría              329 non-null    object
#  5   provincia              329 non-null    object
#  6   Departamento           329 non-null    object
#  7   localidad              329 non-null    object
#  8   nombre                 329 non-null    object
#  9   domicilio              329 non-null    object
#  10  Piso                   329 non-null    object
#  11  código postal          329 non-null    int64
#  12  cod_area               329 non-null    object
#  13  número de teléfono     329 non-null    object
# ...

# %%
df_cines['espacio_INCAA'] = df_cines['espacio_INCAA'].fillna('no')

# %%
df_cines.loc[df_cines.espacio_INCAA==0, 'espacio_INCAA'] = 'no'

# %%
df_cines = df_cines.fillna('s/d')

# %%
df_cines.drop_duplicates()
# Out:
#      cod_localidad  id_provincia  id_departamento Observaciones  \
# 0         10049030            10            10049           s/d
# 1         10091150            10            10091           s/d
# 2         22140060            22            22140           s/d
# 3         26091020            26            26091           s/d
# 4         18007010            18            18007           s/d
# ..             ...           ...              ...           ...
# 324        6455030             6             6455           s/d
# 325        6434010             6             6434           s/d
# 326        6791050             6             6791           s/d
# 327       10049030            10            10049           s/d
# 328        6427010             6             6427           s/d
#
#          categoría     provincia  Departamento    localidad  \
# 0    Salas de cine     Catamarca       Capital    Catamarca
# 1    Salas de cine     Catamarca   Santa Maria  Santa María
# ...

# %%
df_cines.replace('0','no')
# Out:
#      cod_localidad  id_provincia  id_departamento Observaciones  \
# 0         10049030            10            10049           s/d
# 1         10091150            10            10091           s/d
# 2         22140060            22            22140           s/d
# 3         26091020            26            26091           s/d
# 4         18007010            18            18007           s/d
# ..             ...           ...              ...           ...
# 324        6455030             6             6455           s/d
# 325        6434010             6             6434           s/d
# 326        6791050             6             6791           s/d
# 327       10049030            10            10049           s/d
# 328        6427010             6             6427           s/d
#
#          categoría     provincia  Departamento    localidad  \
# 0    Salas de cine     Catamarca       Capital    Catamarca
# 1    Salas de cine     Catamarca   Santa Maria  Santa María
# ...

# %%
df_cines.to_csv('datos/cine/2022-05/cine-06-05-2022/cine-06-05-2022.csv', index=None)
